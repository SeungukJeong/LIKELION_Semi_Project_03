# %% [markdown]
# # ML Models
# #### Using Main branch past preprocessed data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB
from xgboost import XGBClassifier
from lightgbm.sklearn import LGBMClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

import credit_data

import warnings
warnings.filterwarnings("ignore")

# %%
train_data, test_data, train_label, test_label = credit_data.load_data()
print(train_data.shape, test_data.shape, train_label.shape, test_label.shape)
# Out:
# (15906, 67) (6818, 67) (15906, 1) (6818, 1)

# %%
models = [
    ('Logistic', LogisticRegression()),
    ('KNN', KNeighborsClassifier(16)),
    ('SVM', SVC(kernel='rbf', C=100, gamma=0.01)),
    ('DecisionTree', DecisionTreeClassifier(random_state = 0, max_depth = 4)),
    ('RandomForest', RandomForestClassifier(random_state = 0, n_estimators = 100, max_depth = 6)),
    ('NaiveBayes', BernoulliNB(alpha=10)),
    ('XGBoost', XGBClassifier(seed = 0, n_estimators = 200, max_depth = 2, verbosity=0)),
    ('LightGBM', LGBMClassifier(random_state=0, n_estimators = 200, max_depth = 2))]

# %%
# for name, model in models:
#     model.fit(train_data, train_label)
#     print(f'{name}: ', accuracy_score(model.predict(test_data), test_label))

# %%
# clf = LinearDiscriminantAnalysis()
# clf.fit(train_data.todense(), train_label)
# print('Linear Discriminat Analysis:', accuracy_score(clf.predict(test_data), test_label))

# %%
train_data
# Out:
# <15906x67 sparse matrix of type '<class 'numpy.float64'>'
# 	with 270402 stored elements in Compressed Sparse Row format>

# %%
#### NGBoost
from ngboost import NGBClassifier
from ngboost.distns import k_categorical, Bernoulli

ngb_cat = NGBClassifier(Dist=k_categorical(3), verbose=False) # tell ngboost that there are 3 possible outcomes
_ = ngb_cat.fit(train_data, train_label) # Y should have only 3 values: {0,1,2}

# %%
ngb_cat.predict(test_data)
# Out:
# array([2, 2, 2, ..., 2, 1, 2])

# %%
ngb_pred_test = ngb_cat.predict(test_data)

# %%
accuracy_score(ngb_pred_test, test_label)
# Out:
# 0.6915517747139923

# %%
round(accuracy_score(ngb_cat.predict(train_data), train_label),4)
# Out:
# 0.6898

# %%
ngb_cat.predict_proba(test_data)
# Out:
# array([[0.11615147, 0.23131703, 0.6525315 ],
#        [0.13784527, 0.23860816, 0.62354657],
#        [0.1160482 , 0.19928395, 0.68466785],
#        ...,
#        [0.12981473, 0.18012702, 0.69005824],
#        [0.06763661, 0.62196931, 0.31039408],
#        [0.12861968, 0.20450865, 0.66687167]])

# %%
ngb_cat.pred_dist(test_data).params
# Out:
# {'p0': array([0.11615147, 0.13784527, 0.1160482 , ..., 0.12981473, 0.06763661,
#         0.12861968]),
#  'p1': array([0.23131703, 0.23860816, 0.19928395, ..., 0.18012702, 0.62196931,
#         0.20450865]),
#  'p2': array([0.6525315 , 0.62354657, 0.68466785, ..., 0.69005824, 0.31039408,
#         0.66687167])}

# %%
#### Scores 
from ngboost.scores import LogScore, CRPScore 

NGBClassifier(Dist = k_categorical(3), Score = LogScore, verbose=False).fit(train_data, train_label)
# Out:
# NGBClassifier(random_state=RandomState(MT19937) at 0x103E7FB40, verbose=False)

# %%
train_soso = pd.read_csv('train_othrs.csv')
train_soso.head()
# Out:
#    index  age  begin_month  car  career  cluster  days_income  \
# 0      0   38          6.0    1      12       30    10.882416
# 1      1   31          5.0    1       4       15    19.156347
# 2      2   52         22.0    2      12        8    19.131840
# 3      3   41         37.0    1       5       30    11.786962
# 4      4   41         26.0    2       5        5     9.187959
#
#    days_unemployed  edu_type  email  ...  income_type  month_birth  \
# 0             9190         1      1  ...            1          7.0
# 1             9840         2      2  ...            1          7.0
# 2            14653         1      1  ...            2          0.0
# 3            12996         2      1  ...            1         10.0
# 4            12932         1      1  ...            3          9.0
#
#    month_unemployed  occyp_type  phone  reality  week_birth  week_unemployed  \
# 0               6.0           1      1        1         1.0              0.0
# ...

# %%
train_new_label = train_new[['credit']]
train_new = train_new.drop(['credit'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb#ch0000016?line=0'>1</a> train_new_label = train_new[['credit']]
#       <a href='vscode-notebook-cell:/Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb#ch0000016?line=1'>2</a> train_new = train_new.drop(['credit'], axis =1)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf_25/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/tf_25/lib/python3.8/site-packages/pandas/core/frame.py?line=3508'>3509</a>     if is_iterator(key):
# ...

# %%
train_new_label
# Out:
#        credit
# 0         1.0
# 1         1.0
# 2         2.0
# 3         0.0
# 4         2.0
# ...       ...
# 26452     1.0
# 26453     2.0
# 26454     2.0
# 26455     2.0
# 26456     2.0
#
# [26457 rows x 1 columns]

# %%
train_new
# Out:
#        index  age  begin_month  car  career  cluster  days_income  \
# 0          0   38          6.0    1      12       30    10.882416
# 1          1   31          5.0    1       4       15    19.156347
# 2          2   52         22.0    2      12        8    19.131840
# 3          3   41         37.0    1       5       30    11.786962
# 4          4   41         26.0    2       5        5     9.187959
# ...      ...  ...          ...  ...     ...      ...          ...
# 26452  26452   33          2.0    1       5       26    15.999431
# 26453  26453   41         47.0    1       6       23    10.131712
# 26454  26454   27         25.0    2       5       10    24.179549
# 26455  26455   27         59.0    1       0       33    16.679672
# 26456  26456   53          9.0    1       2        9     3.935478
#
#        days_unemployed  edu_type  email  ...  income_total  income_type  \
# 0                 9190         1      1  ...      202500.0            1
# ...

# %%
ngb_cat = NGBClassifier(Dist=k_categorical(3), verbose=False) # tell ngboost that there are 3 possible outcomes
_ = ngb_cat.fit(train_new, train_new_label) # Y should have only 3 values: {0,1,2}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb Cell 19' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb#ch0000018?line=0'>1</a> ngb_cat = NGBClassifier(Dist=k_categorical(3), verbose=False) # tell ngboost that there are 3 possible outcomes
# ----> <a href='vscode-notebook-cell:/Users/seunguk/Documents/likelion/credit-now/ml_model_ngboost.ipynb#ch0000018?line=1'>2</a> _ = ngb_cat.fit(train_new, train_new_label)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf_25/lib/python3.8/site-packages/ngboost/ngboost.py:273, in NGBoost.fit(self, X, Y, X_val, Y_val, sample_weight, val_sample_weight, train_loss_monitor, val_loss_monitor, early_stopping_rounds)
# ...

# %%
accuracy_score(ngb_pred_test, test_label)
